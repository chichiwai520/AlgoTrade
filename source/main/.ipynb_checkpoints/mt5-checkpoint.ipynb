# %%
pip install MetaTrader5
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\chunwaichi\Documents\Python_projects\Algo_trade\source\main\mt5.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> password="iPijcvdF"
#       <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> server="ICMarketsSC-Demo"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> login(login,password,server)
#
# TypeError: 'str' object is not callable

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import MetaTrader5 as mt5
 
# connect to MetaTrader 5
if not mt5.initialize():
    print("initialize() failed")
    mt5.shutdown()

login =51499008
password="iPijcvdF"
server="ICMarketsSC-Demo"
mt5.login(login,password,server)
# Out:
# True

# %%
rates=mt5.copy_rates_from("XAUUSD",mt5.TIMEFRAME_D1,datetime.now(),100)

# %%
rates
# Out:
# array([(1689033600, 1925.19, 1938.45, 1924.38, 1932.09, 72793, 0, 0),
#        (1689120000, 1932.31, 1959.67, 1932.26, 1957.35, 79435, 0, 0),
#        (1689206400, 1957.04, 1963.58, 1952.43, 1960.39, 81084, 0, 0),
#        (1689292800, 1960.27, 1963.77, 1950.95, 1955.45, 79557, 0, 0),
#        (1689552000, 1955.42, 1959.9 , 1945.78, 1954.92, 69205, 0, 0),
#        (1689638400, 1954.69, 1984.42, 1954.61, 1978.73, 81400, 0, 0),
#        (1689724800, 1978.88, 1980.91, 1969.77, 1976.97, 72285, 0, 0),
#        (1689811200, 1976.56, 1987.46, 1965.38, 1969.5 , 79625, 0, 0),
#        (1689897600, 1970.39, 1973.8 , 1956.86, 1961.84, 73394, 0, 0),
#        (1690156800, 1962.1 , 1967.91, 1953.4 , 1954.87, 70532, 0, 0),
#        (1690243200, 1955.28, 1965.67, 1952.5 , 1964.85, 66193, 0, 0),
#        (1690329600, 1964.98, 1978.41, 1962.  , 1972.27, 80852, 0, 0),
#        (1690416000, 1971.51, 1982.2 , 1942.62, 1945.52, 81964, 0, 0),
# ...

# %%
account_info = mt5.account_info()

# %%
account_info.balance
# Out:
# 10000.0

# %%
num_symbols=mt5.symbols_total()

# %%
num_symbols
# Out:
# 2137

# %%
mt5.symbol_info("XAUUSD")._asdict()
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': False,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1701069619,
#  'digits': 2,
#  'spread': 0,
#  'spread_float': True,
#  'ticks_bookdepth': 10,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 2,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 2013.59,
#  'bidhigh': 2018.19,
#  'bidlow': 2000.64,
#  'ask': 2013.59,
#  'askhigh': 2018.26,
#  'asklow': 2000.64,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
import pandas as pd

# %%
ohlc= pd.DataFrame(mt5.copy_rates_from("XAUUSD", mt5.TIMEFRAME_M1,datetime(year=2023,month=11,day=1),10000))
ohlc
# Out:
#             time     open     high      low    close  tick_volume  spread  \
# 0     1698027120  1977.16  1978.19  1976.90  1977.89           39       8
# 1     1698027180  1977.87  1977.93  1977.34  1977.39           21       8
# 2     1698027240  1977.39  1977.66  1977.39  1977.55           18       7
# 3     1698027300  1977.55  1977.55  1977.09  1977.44           28       8
# 4     1698027360  1977.54  1977.71  1977.45  1977.71           11       5
# ...          ...      ...      ...      ...      ...          ...     ...
# 9995  1698825360  1977.36  1977.69  1977.34  1977.69           21       5
# 9996  1698825420  1977.69  1977.83  1977.65  1977.76           33       5
# 9997  1698825480  1977.76  1977.91  1977.66  1977.83           37       5
# 9998  1698825540  1977.83  1977.83  1977.51  1977.67           31       5
# 9999  1698825600  1977.62  1977.62  1977.18  1977.31           30       6
#
#       real_volume
# 0               0
# 1               0
# 2               0
# ...

# %%
ohlc["time"] = pd.to_datetime(ohlc["time"],unit='s')

# %%
ohlc
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2023-10-23 02:12:00  1977.16  1978.19  1976.90  1977.89           39
# 1    2023-10-23 02:13:00  1977.87  1977.93  1977.34  1977.39           21
# 2    2023-10-23 02:14:00  1977.39  1977.66  1977.39  1977.55           18
# 3    2023-10-23 02:15:00  1977.55  1977.55  1977.09  1977.44           28
# 4    2023-10-23 02:16:00  1977.54  1977.71  1977.45  1977.71           11
# ...                  ...      ...      ...      ...      ...          ...
# 9995 2023-11-01 07:56:00  1977.36  1977.69  1977.34  1977.69           21
# 9996 2023-11-01 07:57:00  1977.69  1977.83  1977.65  1977.76           33
# 9997 2023-11-01 07:58:00  1977.76  1977.91  1977.66  1977.83           37
# 9998 2023-11-01 07:59:00  1977.83  1977.83  1977.51  1977.67           31
# 9999 2023-11-01 08:00:00  1977.62  1977.62  1977.18  1977.31           30
#
#       spread  real_volume
# 0          8            0
# ...

# %%
import plotly.express as px 
import nbformat
fig = px.line(ohlc,x = ohlc["time"], y=ohlc['close'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\chunwaichi\Documents\Python_projects\Algo_trade\source\main\mt5.ipynb Cell 15 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> import nbformat
#       <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> fig = px.line(ohlc,x = ohlc["time"], y=ohlc['close'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chunwaichi/Documents/Python_projects/Algo_trade/source/main/mt5.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> fig.show()
#
# File c:\Users\chunwaichi\Documents\Python_projects\Installation\venv\lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
# ...
